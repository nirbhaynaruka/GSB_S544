# %% [raw]
# ---
# self-contained: true
# title: "Mid Term"
# author : "Nirbhay Singh Naruka"
# date : "10/25/2023"
# date-format: long
# format :
#     html:
#         mainfront: sans-serif;
# ---

# %%
import pandas as pd
import numpy as np

from plotnine import ggplot, aes, geom_boxplot, scale_y_continuous, labs, theme, coord_cartesian, scale_y_log10
# from plotnine.scales import scale_colour_viridis
from plotnine.themes import element_text
import requests
from bs4 import BeautifulSoup

# %%
trail = pd.read_csv('national_park_trails.csv')
trail
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        area_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# 1           Denali National Park  Denali National Park     Alaska
# 2     Kenai Fjords National Park                Seward     Alaska
# 3           Denali National Park  Denali National Park     Alaska
# 4           Denali National Park  Denali National Park     Alaska
# ...                          ...                   ...        ...
# 3308     Haleakala National Park                  Kula       Maui
# 3309     Haleakala National Park                  Kula       Maui
# 3310     Haleakala National Park                  Kula       Maui
# 3311     Haleakala National Park                  Kula       Maui
# 3312     Haleakala National Park                  Kula       Maui
#
#        country_name                                         _geoloc  \
# 0     United States            {'lat': 60.18852, 'lng': -149.63156}
# 1     United States            {'lat': 63.73049, 'lng': -148.91968}
# 2     United States              {'lat': 60.18879, 'lng': -149.631}
# 3     United States              {'lat': 63.73661, 'lng': -148.915}
# 4     United States            {'lat': 63.73319, 'lng': -148.89682}
# ...             ...                                             ...
# 3308         Hawaii            {'lat': 20.75275, 'lng': -156.22884}
# 3309         Hawaii  {'lat': 20.714480000000002, 'lng': -156.25072}
# 3310         Hawaii            {'lat': 20.71007, 'lng': -156.25357}
# 3311         Hawaii              {'lat': 20.64981, 'lng': -156.137}
# 3312         Hawaii            {'lat': 20.71449, 'lng': -156.25085}
#
#       popularity     length  elevation_gain  difficulty_rating    route_type  \
# 0        24.8931  15610.598       1161.8976                  5  out and back
# 1        18.0311   6920.162        507.7968                  3  out and back
# 2        17.7821   2896.812         81.9912                  1  out and back
# 3        16.2674   3379.614        119.7864                  1          loop
# 4        12.5935  29772.790       1124.7120                  5  out and back
# ...          ...        ...             ...                ...           ...
# 3308      9.3861  20116.750       1105.8144                  5          loop
# 3309      9.1555  28324.384       1171.9560                  5  out and back
# 3310      8.5066    321.868          3.9624                  1  out and back
# 3311      8.3240  19312.080       1670.9136                  5  out and back
# 3312      2.4176   8368.568        510.8448                  3          loop
#
#       visitor_usage  avg_rating  num_reviews  \
# 0               3.0         5.0          423
# 1               1.0         4.5          260
# 2               3.0         4.5          224
# 3               2.0         4.5          237
# 4               1.0         4.5          110
# ...             ...         ...          ...
# 3308            2.0         4.5           43
# 3309            2.0         5.0           22
# 3310            NaN         4.5           31
# 3311            1.0         4.0            8
# 3312            2.0         4.5           45
#
#                                                features  \
# 0     ['dogs-no', 'forest', 'river', 'views', 'water...
# 1     ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2     ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3     ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4     ['dogs-no', 'lake', 'views', 'wild-flowers', '...
# ...                                                 ...
# 3308               ['dogs-no', 'views', 'wild-flowers']
# 3309                   ['dogs-no', 'views', 'wildlife']
# 3310                       ['dogs-no', 'kids', 'views']
# 3311                   ['dogs-no', 'views', 'wildlife']
# 3312                                          ['views']
#
#                                              activities units
# 0     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1     ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                                 ['hiking', 'walking']     i
# 3     ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4     ['birding', 'fishing', 'hiking', 'nature-trips...     i
# ...                                                 ...   ...
# 3308              ['birding', 'hiking', 'nature-trips']     m
# 3309               ['backpacking', 'camping', 'hiking']     m
# 3310                              ['hiking', 'walking']     m
# 3311                                         ['hiking']     m
# 3312                                         ['hiking']     m
#
# [3313 rows x 18 columns]

# %% [markdown]
# Question 1.1 [10 points]
#
# What is the length in miles of the fourth longest trail in California?

# %%
# filter first for California and then sort from highest to lowest
cali = trail[trail['state_name'] == 'California']
sort = cali.sort_values(by='length', ascending=False).iloc[3]['length']
print(sort/1609.34)
# Out:
# 145.20000000000002

# %% [markdown]
# Question 1.2 [10 points]
#
# Consider an “easy” trail to be one that has an elevation gain of less than 500 meters, a distance of less than 5 kilometers, and a difficulty rating below 4.
#
# Which California National Park has the highest average rating of its “easy” trails?

# %%
def easy(trails):
    return trails['elevation_gain'] < 500 and trails['length'] < 5000 and trails['difficulty_rating'] < 4

easy_trail = cali[cali.apply(easy, axis=1)]

average_rating = easy_trail.groupby('area_name')['avg_rating'].mean()
park = average_rating.idxmax()
print(park)
# Out:
# Kings Canyon National Park

# %% [markdown]
# Question 1.3 [15 points]
#
# How many National Parks contain the word “Land” somewhere in their name? (if the word appears as part of a longer word, like “Candyland”, this counts too)

# %%
all_names = trail['name'].unique()
land = 0
for park_name in all_names:
    if 'land' in park_name.lower():
        land += 1
print(land)
# Out:
# 61

# %% [markdown]
# Question 1.4 [15 points]
#
# Consider the following plot, made from a dataset called np_trails_new. Although you can see the code that made the plot, you do not see the code that made the np_trails_new object.
#
# Your job in this question is to create the np_trails_new object. You’ll know when you have succeeded, because the code provided will produce the plot.
#
# In Canvas, turn in the values of the first row of the np_trails_new object.
#
# (If your dataset has more columns than seem to be available, only include the ones that were absolutely necessary to keep in this analysis.)

# %%
# np_trails_new =

# (ggplot(np_trails_new, aes(x="score"))
# + geom_density()
# + facet_wrap('~ measure', scales = 'free')
# + ggtitle("Overall distribution of various trail scores in National parks")
# )

# %% [markdown]
# Question 1.5 [20 points]
#
# Recreate the plot below, by filling in the blanks in the code on Canvas.

# %%
(ggplot(cali, aes(x="area_name", y="num_reviews", fill="state_name"))
 + geom_boxplot()
 + scale_y_continuous()  # Adjusting the y-axis limits
+ scale_fill_manual(values=["red", "blue", "green"], guide = False)
 + labs(
     x="",
     y="",
     title="Number of reviews per trail for CA Parks"
 )
 + coord_cartesian(ylim=(0, 100))  # Adjusting the y-axis limits without removing data points
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Part Two: Programming [80 points]**

# %% [markdown]
# Question 2.1 [30 points]
#
# Write a functions to help recommend trails to a user. The function will have as its input the dataset and the name of a National Park, and the following optional arguments:
#
# A minimum trail elevation gain (in meters)
# A maximum trail elevation gain (in meters)
# A minimum trail rating
# The type of trail
# (Note: “optional” here means that the function can run even if the user doesn’t supply these arguments, not that they are optional for you to include in your function definition.)
#
# The function should return all the trails that fit the supplied criteria. You may assume that the variable names of any inputted dataset match the np_trails dataset.

# %%
def recommend_trails(dataset, park_name, min_elev=0, max_elev=float('inf'), min_rating=0, trail_type=None):
    filtered_trails = pd.DataFrame(columns=dataset.columns)
    for index, row in dataset.iterrows():
        if row['area_name'] == park_name and min_elev <= row['elevation_gain'] <= max_elev and row['avg_rating'] >= min_rating:
            if trail_type is None or row['route_type'] == trail_type:
                filtered_trails = filtered_trails.append(row, ignore_index=True)

    return filtered_trails

np_trails = trail

# %%
recommend_trails(np_trails, "Haleakala National Park", min_elev=1000, min_rating=4)
# Out:
# <ipython-input-115-25db242b1d8f>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#    trail_id                                  name                area_name  \
# 0  10008302  Silversword Loop Via Halemau'u Trail  Haleakala National Park
# 1  10236001                   Keonehe'ehe'e Trail  Haleakala National Park
# 2  10014989                           Kaupo Trail  Haleakala National Park
#
#   city_name state_name country_name  \
# 0      Kula       Maui       Hawaii
# 1      Kula       Maui       Hawaii
# 2      Kula       Maui       Hawaii
#
#                                           _geoloc  popularity     length  \
# 0            {'lat': 20.75275, 'lng': -156.22884}      9.3861  20116.750
# 1  {'lat': 20.714480000000002, 'lng': -156.25072}      9.1555  28324.384
# 2              {'lat': 20.64981, 'lng': -156.137}      8.3240  19312.080
#
#    elevation_gain difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1105.8144                 5          loop            2.0         4.5
# 1       1171.9560                 5  out and back            2.0         5.0
# 2       1670.9136                 5  out and back            1.0         4.0
#
#   num_reviews                              features  \
# 0          43  ['dogs-no', 'views', 'wild-flowers']
# 1          22      ['dogs-no', 'views', 'wildlife']
# 2           8      ['dogs-no', 'views', 'wildlife']
#
#                               activities units
# 0  ['birding', 'hiking', 'nature-trips']     m
# 1   ['backpacking', 'camping', 'hiking']     m
# 2                             ['hiking']     m

# %% [markdown]
# Question 2.2 [30 points]
#
# It’s reasonable to think we might also want to search for hikes according to climate. Therefore, we will scrape the average temperatures for each U.S. state from the following website:
#
# https://www.extremeweatherwatch.com/us-state-averages
# Write a function that takes one optional arguent, month.
#
# The function should scrape the temperature website above for the desired month. If no month is specified then it should scrape the overall average temperatures. The function should return a data frame of the temperatures for the specified month in the names of the temperature columns.

# %%
def scrape_temps(month=None):
    my_url = "https://www.extremeweatherwatch.com/us-state-averages"
    updated_url = f"{my_url}/month-{month.lower()}" if month else my_url
    response = requests.get(updated_url)
    # print(response.status_code)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find_all("table",attrs={"class": "bordered-table sort-table"})[0]
    data = []
    for row in table.find_all('tr')[1:]:
      columns = row.find_all('td')
      if len(columns) > 0:
        city, high, low, Precipitation = [cell.get_text(strip=True) for cell in columns]
        data.append([city, high, low, Precipitation])
    df = pd.DataFrame(data, columns=['City', 'High-F', 'Low-F', 'Precipitation'])
    df
    return df

# %%
scrape_temps(month="january")
# Out:
#               City High-F Low-F Precipitation
# 0          Alabama   56.1  34.5           5.3
# 1           Alaska   10.7  -2.4           2.8
# 2          Arizona   55.7  30.6           1.2
# 3         Arkansas   50.0  30.5           3.8
# 4       California   54.6  35.0           4.1
# 5         Colorado   38.9  13.7           1.1
# 6      Connecticut   36.0  18.5           3.6
# 7         Delaware   43.9  26.5           3.3
# 8          Florida   69.5  47.0           3.3
# 9          Georgia   57.8  35.6           4.5
# 10       Hawaii[1]   77.0  62.5           3.8
# 11           Idaho   33.2  17.1           2.8
# 12        Illinois   34.7  18.6           2.3
# 13         Indiana   35.6  19.8           2.9
# 14            Iowa   28.1  10.9           1.0
# 15          Kansas   42.6  19.5           0.7
# 16        Kentucky   43.5  25.4           3.7
# 17       Louisiana   60.0  39.8           5.7
# 18           Maine   24.7   5.7           3.3
# 19        Maryland   42.5  25.3           3.2
# 20   Massachusetts   34.8  17.1           3.7
# 21        Michigan   27.6  12.8           2.1
# 22       Minnesota   19.2   0.9           0.8
# 23     Mississippi   56.0  35.2           5.5
# 24        Missouri   40.2  21.5           2.1
# 25         Montana   30.7  11.4           1.2
# 26        Nebraska   36.3  13.9           0.5
# 27          Nevada   43.5  22.1           1.2
# 28   New Hampshire   28.7   9.5           3.3
# 29      New Jersey   40.3  23.2           3.5
# 30      New Mexico   49.7  21.7           0.7
# 31        New York   30.2  12.9           3.1
# 32  North Carolina   51.3  30.3           3.9
# 33    North Dakota   19.9   1.0           0.5
# 34            Ohio   35.9  20.3           2.9
# 35        Oklahoma   50.0  26.6           1.6
# 36          Oregon   41.0  26.1           4.5
# 37    Pennsylvania   34.7  18.5           3.2
# 38    Rhode Island   37.5  20.7           3.9
# 39  South Carolina   56.4  34.3           3.8
# 40    South Dakota   28.6   8.2           0.5
# 41       Tennessee   47.4  28.4           4.6
# 42           Texas   59.5  34.8           1.7
# 43            Utah   38.2  17.8           1.2
# 44         Vermont   26.8   7.9           3.1
# 45        Virginia   45.6  26.1           3.4
# 46      Washington   37.4  26.3           6.2
# 47   West Virginia   40.3  22.5           3.5
# 48       Wisconsin   23.8   6.7           1.2
# 49         Wyoming   32.4  11.1           1.0

# %% [markdown]
# Question 2.3 [20 points]
#
# I am looking for a trail that is:
#
# 1000-3000 meters of elevation (I like mountains, but not too big.)
#
# Rated at least a 4.5 on average
#
# A loop trail (I don’t like to retrace my steps)
#
# Not too cold in the summer, even at the peak
#
# Use your recommend_trails function to find me a few good options.
#
# Use your second function (scrape_temps) to gather information on temperatures for the summer months (i.e. May, June, July, August) in the states for these trails.
#
# Merge these two datasets, so I can see all the recommended trails alongside their summer temps. If you were unable to scrape the information from the website, then feel free to import the temp_data.csv file and use average temperatures instead of summer temperatures to complete this question.
#
# Convert the temperatures of the states to be the temperatures at the peak elevation of my recommended hikes. The temperature decreases by about 5.4 degrees Fahrenheit (or 9.8 degrees Celsius) for every 1000 feet you go up in elevation
#
# Note: In this question, many points will be deducted for copy-pasting similar code many times, and a small penalty will be deducted for use of a for loop.

# %%
defi = {
    'elevation_min': 1000,
    'elevation_max': 3000,
    'min_rating': 4.5,
    'is_loop': True
}

# Filtering the data to select trails that meet the elevation and rating criteria
filtered_trails = trail[
    (trail['elevation_gain'] >= defi['elevation_min']) &
    (trail['elevation_gain'] <= defi['elevation_max']) &
    (trail['avg_rating'] >= defi['min_rating'])
    # (trail['is_loop'] == criteria['is_loop'])
]
recommended_trails_info = filtered_trails[['state_name', 'elevation_gain']]
print(recommended_trails_info)
months = ['may', 'june', 'july', 'august']
summer_temperatures = pd.DataFrame()

for month in months:
    temps = scrape_temps(month)
    summer_temperatures = pd.concat([summer_temperatures, temps], axis=0)

summer_temperatures.rename(columns={'City': 'state_name', 'High-F': 'temperature_high_F'}, inplace=True)
merged_data = recommended_trails_info.merge(summer_temperatures, on='state_name')

merged_data['elevation_gain_ft'] = merged_data['elevation_gain'] * 3.28084

temperature_adjustment = (merged_data['elevation_gain_ft'] / 1000) * 5.4
merged_data['temperature_high_F'] = merged_data['temperature_high_F'].astype(float) - temperature_adjustment
merged_data
# Out:
#      state_name  elevation_gain
# 0        Alaska       1161.8976
# 4        Alaska       1124.7120
# 5        Alaska       1178.9664
# 13       Alaska       1292.9616
# 19       Alaska       1385.9256
# ...         ...             ...
# 3282     Hawaii       1118.9208
# 3283     Hawaii       1143.0000
# 3285     Hawaii       1045.7688
# 3308       Maui       1105.8144
# 3309       Maui       1171.9560
#
# [429 rows x 2 columns]
#      state_name  elevation_gain  temperature_high_F Low-F Precipitation  \
# 0        Alaska       1161.8976           28.315199  31.2           2.1
# 1        Alaska       1161.8976           39.315199  41.9           2.4
# 2        Alaska       1161.8976           41.715199  45.9           3.5
# 3        Alaska       1161.8976           37.315199  42.8           4.6
# 4        Alaska       1124.7120           28.973999  31.2           2.1
# ...         ...             ...                 ...   ...           ...
# 1687    Wyoming       1047.9024           61.734799  49.0           1.0
# 1688    Wyoming       1437.7416           36.528199  36.0           2.4
# 1689    Wyoming       1437.7416           47.728199  44.1           1.7
# 1690    Wyoming       1437.7416           56.628199  50.9           1.2
# 1691    Wyoming       1437.7416           54.828199  49.0           1.0
#
#       elevation_gain_ft
# 0           3812.000122
# 1           3812.000122
# 2           3812.000122
# 3           3812.000122
# 4           3690.000118
# ...                 ...
# 1687        3438.000110
# 1688        4717.000151
# 1689        4717.000151
# 1690        4717.000151
# 1691        4717.000151
#
# [1692 rows x 6 columns]

# %%
# df = pd.DataFrame(merged_data, columns=['State Name', 'Elev Gain', 'Temp High', 'Temp Low'])
# df
